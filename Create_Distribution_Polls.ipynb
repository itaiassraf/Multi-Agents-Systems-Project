# %%
import pandas as pd

# Utility values
util1 = 20
util2 = 10
no_vote_utils = [1, 2, 3]

# Number of unique voters to consider (100-150,000)

voter_range = [100,10100,100000,1000000]
# Function to get vote difference categories based on the number of voters
def get_vote_differences(voters):
    if voters <= 10000:
        return {
            "small": range(1, 11),
            "medium": range(10, 26),
            "large": range(40, 101)
        }
    else:
        return {
            "small": range(20, 41),
            "medium": range(50, 100),
            "large": range(101, 100000)
        }

# Generate samples
samples = []
for voters in voter_range:
    vote_differences = get_vote_differences(voters)
    for diff_type, diff_range in vote_differences.items():
        for no_vote_util in no_vote_utils:
            vote_diff = random.choice(diff_range)
            sample = {
                "Voters": voters,
                "Util1": util1,
                "Util2": util2,
                "NoVoteUtil": no_vote_util,
                "VoteDifference": vote_diff,
                "DifferenceType": diff_type
            }
            samples.append(sample)

# Convert to DataFrame
samples_df = pd.DataFrame(samples)

# %%
samples_df

# %%
samples_df.to_csv("samples.csv", index=False)

# %% [markdown]
# ### **Calculate The Difference Between Candidates**

# %%
# Given differences
def calculate_votes(differences,total_voters):
  # Calculate votes for each candidate
  results = []
  for diff in differences:
      V1 = (total_voters + diff) // 2
      V2 = (total_voters - diff) // 2
      results.append({"Difference": diff, "Votes_Candidate1": V1, "Votes_Candidate2": V2})

  # Convert to DataFrame
  results_df = pd.DataFrame(results)
  return results_df

#example:
results_df = calculate_votes([22,12,42,60,70,80,220,340,160],100100)
# Out:
#    Difference  Votes_Candidate1  Votes_Candidate2
# 0          22             50061             50039
# 1          12             50056             50044
# 2          42             50071             50029
# 3          60             50080             50020
# 4          70             50085             50015
# 5          80             50090             50010
# 6         220             50160             49940
# 7         340             50220             49880
# 8         160             50130             49970
